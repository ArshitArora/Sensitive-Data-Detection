# %% [markdown]
# <a href="https://colab.research.google.com/github/DhilipSanjay/Detection-of-Sensitive-Data-Exposure-in-Images/blob/main/Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image Classification to detect sensitive data exposure
#
# ## Importing libraries and downloading the dataset

# %%
# Importing the necessary libraries
import tensorflow as tf
import numpy as np
import os

# Downloading the dataset
git_folder = "/content/Detection-of-Sensitive-Data-Exposure-in-Images"
if os.path.exists(git_folder) == False:
  # !git clone https://github.com/DhilipSanjay/Detection-of-Sensitive-Data-Exposure-in-Images.git

training_folder = git_folder + "/dataset/training"
validation_folder = git_folder + "/dataset/validation"

# %%
train_sensitive_dir = os.path.join(training_folder + "/sensitive")
train_nonsensitive_dir = os.path.join(training_folder + "/nonsensitive")
validation_sensitive_dir = os.path.join(validation_folder + "/sensitive")
validation_nonsensitive_dir = os.path.join(validation_folder + "/nonsensitive")

# Image Dataset size
print('Total training sensitive images:', len(os.listdir(train_sensitive_dir)))
print('Total training nonsensitive images:', len(os.listdir(train_nonsensitive_dir)))
print('Total validation sensitive images:', len(os.listdir(validation_sensitive_dir)))
print('Total validation nonsensitive images:', len(os.listdir(validation_nonsensitive_dir)))
# Out:
# Total training sensitive images: 300
# Total training nonsensitive images: 300
# Total validation sensitive images: 50
# Total validation nonsensitive images: 50

# %% [markdown]
# ## Sample Data

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

train_sensitive_dir = os.path.join(training_folder+"/sensitive")
train_nonsensitive_dir = os.path.join(training_folder+"/nonsensitive")
train_sensitive_names = os.listdir(train_sensitive_dir)
train_nonsensitive_names = os.listdir(train_nonsensitive_dir)

pic_index += 8
next_sensitive_pix = [os.path.join(train_sensitive_dir, fname)
                for fname in train_sensitive_names[pic_index-8:pic_index]]
next_nonsensitive_pix = [os.path.join(train_nonsensitive_dir, fname)
                for fname in train_nonsensitive_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_sensitive_pix+next_nonsensitive_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# ## Model

# %%
# Callbacks to cancel training after reaching a desired accuracy
# This is done to avoid overfitting
DESIRED_ACCURACY = 0.98

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if logs.get('accuracy') > DESIRED_ACCURACY:
      print("Reached 98% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()

# Sequential - defines a SEQUENCE of layers in the neural network.
model = tf.keras.models.Sequential([
  # 2D Convolution Layer - Filter, Kernel_size, activation fn
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
  # Max pooling operation for 2D data - Pool size
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  # Flattens the input. Does not affect the batch size.
  tf.keras.layers.Flatten(),
  # Regular densely-connected Neural Network layer with ReLU activation function.
  tf.keras.layers.Dense(512, activation='relu'),
  # Regular densely-connected Neural Network layer with sigmoid activation function.
  tf.keras.layers.Dense(1, activation='sigmoid')
])

from tensorflow.keras.optimizers import RMSprop

# model.compile - Configures the model for training.
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Adam -  optimization algorithm used instead of the classical stochastic gradient descent procedure to update network weights.

# Display the summary of the model
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 34, 34, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 17, 17, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 15, 15, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 7, 7, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 512)                 │       6,423,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,811,969 (25.99 MB)
#  Trainable params: 6,811,969 (25.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Preprocessing, Data Augmentation & Training

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Rescaling - 1/255 is to transform every pixel value from range [0,255] -> [0,1]
# Performing image augmentation for training data
train_datagen = ImageDataGenerator(rescale=1/255,
                                  rotation_range=20,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  fill_mode='nearest')
validation_datagen = ImageDataGenerator(rescale=1/255)

# flow_from_directory - Takes the path to a directory & generates batches of data.
train_generator = train_datagen.flow_from_directory(
        training_folder,
        target_size=(150, 150),
        batch_size=30,
        class_mode='binary',
        shuffle=True
       )

validation_generator = validation_datagen.flow_from_directory(
        validation_folder,
        target_size=(150, 150),
        batch_size=5,
        class_mode='binary',
        shuffle=True
        )

num_epochs = 500
# model.fit - Train the model for a fixed number of epochs
history = model.fit(
      train_generator,
      steps_per_epoch=10,
      epochs=num_epochs,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8,
      callbacks=[callbacks])
# Out:
# Found 600 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 435ms/step - accuracy: 0.5084 - loss: 0.8771 - val_accuracy: 0.7250 - val_loss: 0.6613
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.6688 - loss: 0.6589 - val_accuracy: 0.7000 - val_loss: 0.5487
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.6500 - val_loss: 0.7029
# Epoch 4/500
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 285ms/step - accuracy: 0.6934 - loss: 0.5627 - val_accuracy: 0.8500 - val_loss: 0.3150
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.7290 - loss: 0.5286 - val_accuracy: 0.8000 - val_loss: 0.4445
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.7500 - val_loss: 0.5016
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 282ms/step - accuracy: 0.7604 - loss: 0.5268 - val_accuracy: 0.8500 - val_loss: 0.3965
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.7809 - loss: 0.4860 - val_accuracy: 0.8500 - val_loss: 0.3179
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9000 - val_loss: 0.2555
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 0.8157 - loss: 0.4396 - val_accuracy: 0.9000 - val_loss: 0.2517
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8259 - loss: 0.4260 - val_accuracy: 0.8750 - val_loss: 0.3574
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9000 - val_loss: 0.3939
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 379ms/step - accuracy: 0.8339 - loss: 0.4114 - val_accuracy: 0.9000 - val_loss: 0.2574
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.8096 - loss: 0.3977 - val_accuracy: 0.8500 - val_loss: 0.2964
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 0.3911
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 275ms/step - accuracy: 0.7325 - loss: 0.5331 - val_accuracy: 0.9250 - val_loss: 0.3990
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.8525 - loss: 0.4402 - val_accuracy: 0.9250 - val_loss: 0.1909
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9000 - val_loss: 0.2780
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 290ms/step - accuracy: 0.7713 - loss: 0.4413 - val_accuracy: 0.9250 - val_loss: 0.2284
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.7711 - loss: 0.4565 - val_accuracy: 0.9250 - val_loss: 0.2841
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9000 - val_loss: 0.2325
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 336ms/step - accuracy: 0.8014 - loss: 0.4497 - val_accuracy: 0.9250 - val_loss: 0.2762
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.8493 - loss: 0.3868 - val_accuracy: 0.9750 - val_loss: 0.1243
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9000 - val_loss: 0.2569
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 302ms/step - accuracy: 0.8502 - loss: 0.3178 - val_accuracy: 0.9750 - val_loss: 0.1762
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8385 - loss: 0.3986 - val_accuracy: 0.9250 - val_loss: 0.1819
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1820
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - accuracy: 0.7852 - loss: 0.4682 - val_accuracy: 0.9000 - val_loss: 0.2307
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - accuracy: 0.8376 - loss: 0.3903 - val_accuracy: 0.9250 - val_loss: 0.2090
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8500 - val_loss: 0.2182
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 280ms/step - accuracy: 0.8550 - loss: 0.3603 - val_accuracy: 0.9250 - val_loss: 0.1903
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.8501 - loss: 0.3302 - val_accuracy: 0.9500 - val_loss: 0.1491
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1448
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - accuracy: 0.9057 - loss: 0.2572 - val_accuracy: 0.8250 - val_loss: 0.3754
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - accuracy: 0.8254 - loss: 0.4396 - val_accuracy: 0.9750 - val_loss: 0.1435
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9000 - val_loss: 0.2546
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - accuracy: 0.7813 - loss: 0.4378 - val_accuracy: 0.8750 - val_loss: 0.2982
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.8329 - loss: 0.4244 - val_accuracy: 0.9250 - val_loss: 0.1885
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.1473
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 275ms/step - accuracy: 0.8690 - loss: 0.3254 - val_accuracy: 1.0000 - val_loss: 0.0855
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.8920 - loss: 0.2924 - val_accuracy: 0.9750 - val_loss: 0.0847
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0552
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - accuracy: 0.8279 - loss: 0.4228 - val_accuracy: 0.9750 - val_loss: 0.1518
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.8919 - loss: 0.2668 - val_accuracy: 1.0000 - val_loss: 0.0789
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0728
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.8556 - loss: 0.3472 - val_accuracy: 0.9750 - val_loss: 0.1157
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.8764 - loss: 0.3192 - val_accuracy: 0.9250 - val_loss: 0.1998
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.2246
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - accuracy: 0.8575 - loss: 0.2840 - val_accuracy: 0.9250 - val_loss: 0.1214
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.8584 - loss: 0.2964 - val_accuracy: 0.9750 - val_loss: 0.1385
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1963
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 285ms/step - accuracy: 0.8494 - loss: 0.3322 - val_accuracy: 0.9750 - val_loss: 0.0872
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.8869 - loss: 0.2480 - val_accuracy: 0.9500 - val_loss: 0.1333
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1441
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.9006 - loss: 0.2740 - val_accuracy: 0.9000 - val_loss: 0.2215
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9014 - loss: 0.2430 - val_accuracy: 0.8750 - val_loss: 0.3066
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.7500 - val_loss: 0.6276
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 288ms/step - accuracy: 0.8889 - loss: 0.3013 - val_accuracy: 0.9250 - val_loss: 0.1590
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.8712 - loss: 0.3023 - val_accuracy: 0.8750 - val_loss: 0.1781
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8000 - val_loss: 0.2777
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step - accuracy: 0.8482 - loss: 0.3246 - val_accuracy: 1.0000 - val_loss: 0.0315
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.8949 - loss: 0.2072 - val_accuracy: 1.0000 - val_loss: 0.0411
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0489
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step - accuracy: 0.8814 - loss: 0.2691 - val_accuracy: 0.9750 - val_loss: 0.0733
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9231 - loss: 0.1884 - val_accuracy: 0.9750 - val_loss: 0.0823
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0549
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 283ms/step - accuracy: 0.9058 - loss: 0.2246 - val_accuracy: 1.0000 - val_loss: 0.0457
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.9175 - loss: 0.2076 - val_accuracy: 1.0000 - val_loss: 0.0187
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1412
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 352ms/step - accuracy: 0.9339 - loss: 0.1788 - val_accuracy: 1.0000 - val_loss: 0.0172
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.8961 - loss: 0.2320 - val_accuracy: 0.9500 - val_loss: 0.1249
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0996
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.9098 - loss: 0.2457 - val_accuracy: 0.9750 - val_loss: 0.0470
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.9424 - loss: 0.1940 - val_accuracy: 0.9750 - val_loss: 0.0851
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0643
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 280ms/step - accuracy: 0.9192 - loss: 0.1873 - val_accuracy: 0.9750 - val_loss: 0.0855
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9086 - loss: 0.1864 - val_accuracy: 1.0000 - val_loss: 0.0389
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.0645
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 407ms/step - accuracy: 0.9206 - loss: 0.1895 - val_accuracy: 0.9750 - val_loss: 0.0851
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.9493 - loss: 0.1573 - val_accuracy: 0.9750 - val_loss: 0.0574
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0162
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 420ms/step - accuracy: 0.9409 - loss: 0.1426 - val_accuracy: 0.9500 - val_loss: 0.1640
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.9043 - loss: 0.2098 - val_accuracy: 1.0000 - val_loss: 0.0435
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0625
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 283ms/step - accuracy: 0.9088 - loss: 0.2401 - val_accuracy: 0.9500 - val_loss: 0.0879
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9300 - loss: 0.2297 - val_accuracy: 1.0000 - val_loss: 0.0743
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0457
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 377ms/step - accuracy: 0.8754 - loss: 0.2308 - val_accuracy: 0.9750 - val_loss: 0.0536
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - accuracy: 0.9327 - loss: 0.1828 - val_accuracy: 1.0000 - val_loss: 0.0275
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0181
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - accuracy: 0.8900 - loss: 0.2605 - val_accuracy: 1.0000 - val_loss: 0.0800
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.9187 - loss: 0.1947 - val_accuracy: 0.9750 - val_loss: 0.1038
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0647
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 279ms/step - accuracy: 0.9253 - loss: 0.1485 - val_accuracy: 0.9000 - val_loss: 0.1629
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.9484 - loss: 0.1448 - val_accuracy: 0.9250 - val_loss: 0.1936
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0670
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 347ms/step - accuracy: 0.9540 - loss: 0.1770 - val_accuracy: 0.9250 - val_loss: 0.1671
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.9483 - loss: 0.1658 - val_accuracy: 1.0000 - val_loss: 0.0598
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0312
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - accuracy: 0.9522 - loss: 0.1222 - val_accuracy: 0.9500 - val_loss: 0.0879
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9649 - loss: 0.1009 - val_accuracy: 1.0000 - val_loss: 0.0163
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0239
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 413ms/step - accuracy: 0.9335 - loss: 0.1380 - val_accuracy: 0.9500 - val_loss: 0.1789
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.9526 - loss: 0.1330 - val_accuracy: 0.9500 - val_loss: 0.0952
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9000 - val_loss: 0.2142
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 287ms/step - accuracy: 0.9644 - loss: 0.1262 - val_accuracy: 0.9500 - val_loss: 0.1596
# Epoch 107/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.9107 - loss: 0.2309 - val_accuracy: 0.9750 - val_loss: 0.0901
# Epoch 108/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.0928
# Epoch 109/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 292ms/step - accuracy: 0.9567 - loss: 0.1158 - val_accuracy: 0.9750 - val_loss: 0.0677
# Epoch 110/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.9262 - loss: 0.1884 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 111/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9000 - val_loss: 0.1382
# Epoch 112/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 283ms/step - accuracy: 0.8995 - loss: 0.3112 - val_accuracy: 1.0000 - val_loss: 0.0874
# Epoch 113/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8771 - loss: 0.2672 - val_accuracy: 1.0000 - val_loss: 0.0748
# Epoch 114/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1306
# Epoch 115/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 433ms/step - accuracy: 0.9199 - loss: 0.1779 - val_accuracy: 0.8500 - val_loss: 0.3417
# Epoch 116/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.9013 - loss: 0.2295 - val_accuracy: 0.9500 - val_loss: 0.1498
# Epoch 117/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0285
# Epoch 118/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 296ms/step - accuracy: 0.9247 - loss: 0.2009 - val_accuracy: 0.9250 - val_loss: 0.2017
# Epoch 119/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9565 - loss: 0.1139 - val_accuracy: 0.9500 - val_loss: 0.0661
# Epoch 120/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0277
# Epoch 121/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - accuracy: 0.9517 - loss: 0.1128 - val_accuracy: 1.0000 - val_loss: 0.0284
# Epoch 122/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.9713 - loss: 0.1005 - val_accuracy: 1.0000 - val_loss: 0.0372
# Epoch 123/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0554
# Epoch 124/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 287ms/step - accuracy: 0.9527 - loss: 0.1216 - val_accuracy: 0.9250 - val_loss: 0.1538
# Epoch 125/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.9249 - loss: 0.1740 - val_accuracy: 0.8750 - val_loss: 0.1602
# Epoch 126/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9000 - val_loss: 0.2947
# Epoch 127/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - accuracy: 0.9589 - loss: 0.1031 - val_accuracy: 1.0000 - val_loss: 0.0215
# Epoch 128/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.9497 - loss: 0.1151 - val_accuracy: 0.9000 - val_loss: 0.1394
# Epoch 129/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.0394
# Epoch 130/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.9745 - loss: 0.0836 - val_accuracy: 1.0000 - val_loss: 0.0326
# Epoch 131/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.9689 - loss: 0.0930 - val_accuracy: 0.8500 - val_loss: 0.5149
# Epoch 132/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1109
# Epoch 133/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - accuracy: 0.9567 - loss: 0.1248 - val_accuracy: 0.9500 - val_loss: 0.0938
# Epoch 134/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.9642 - loss: 0.1240 - val_accuracy: 0.9750 - val_loss: 0.1407
# Epoch 135/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.0814
# Epoch 136/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 277ms/step - accuracy: 0.9560 - loss: 0.1505 - val_accuracy: 0.9500 - val_loss: 0.1258
# Epoch 137/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9281 - loss: 0.1756 - val_accuracy: 0.9500 - val_loss: 0.0914
# Epoch 138/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.0761
# Epoch 139/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 281ms/step - accuracy: 0.9721 - loss: 0.0886 - val_accuracy: 0.9750 - val_loss: 0.0429
# Epoch 140/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.9333 - loss: 0.2155 - val_accuracy: 0.9500 - val_loss: 0.1540
# Epoch 141/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1187
# Epoch 142/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 293ms/step - accuracy: 0.9416 - loss: 0.1349 - val_accuracy: 0.9750 - val_loss: 0.0370
# Epoch 143/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9671 - loss: 0.1194 - val_accuracy: 0.9500 - val_loss: 0.0797
# Epoch 144/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1691
# Epoch 145/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 287ms/step - accuracy: 0.9636 - loss: 0.1027 - val_accuracy: 0.9250 - val_loss: 0.2481
# Epoch 146/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9872 - loss: 0.0756 - val_accuracy: 0.9750 - val_loss: 0.0298
# Epoch 147/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 148/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 423ms/step - accuracy: 0.9464 - loss: 0.1249 - val_accuracy: 0.9500 - val_loss: 0.1015
# Epoch 149/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.9389 - loss: 0.1985 - val_accuracy: 1.0000 - val_loss: 0.0611
# Epoch 150/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1502
# Epoch 151/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 273ms/step - accuracy: 0.9738 - loss: 0.0779 - val_accuracy: 0.9500 - val_loss: 0.0952
# Epoch 152/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9434 - loss: 0.1145 - val_accuracy: 0.9750 - val_loss: 0.0556
# Epoch 153/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0585
# Epoch 154/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - accuracy: 0.9527 - loss: 0.0874 - val_accuracy: 0.9500 - val_loss: 0.0664
# Epoch 155/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9833 - loss: 0.0671 - val_accuracy: 0.9250 - val_loss: 0.2052
# Epoch 156/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8500 - val_loss: 0.4956
# Epoch 157/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - accuracy: 0.9694 - loss: 0.0734 - val_accuracy: 0.9500 - val_loss: 0.1294
# Epoch 158/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9590 - loss: 0.0944 - val_accuracy: 0.9250 - val_loss: 0.2373
# Epoch 159/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9000 - val_loss: 0.1903
# Epoch 160/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - accuracy: 0.9556 - loss: 0.1504 - val_accuracy: 0.8750 - val_loss: 0.1927
# Epoch 161/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9529 - loss: 0.1169 - val_accuracy: 0.9500 - val_loss: 0.0658
# Epoch 162/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.8500 - val_loss: 0.1768
# Epoch 163/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 303ms/step - accuracy: 0.9608 - loss: 0.0686 - val_accuracy: 0.9500 - val_loss: 0.0716
# Epoch 164/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9687 - loss: 0.1220 - val_accuracy: 0.9750 - val_loss: 0.0404
# Epoch 165/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0163
# Epoch 166/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 417ms/step - accuracy: 0.9481 - loss: 0.1411 - val_accuracy: 0.9750 - val_loss: 0.1558
# Epoch 167/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9586 - loss: 0.1401 - val_accuracy: 0.9750 - val_loss: 0.0586
# Epoch 168/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0164
# Epoch 169/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 413ms/step - accuracy: 0.9653 - loss: 0.1078 - val_accuracy: 1.0000 - val_loss: 0.0175
# Epoch 170/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.9612 - loss: 0.0932 - val_accuracy: 0.9750 - val_loss: 0.0894
# Epoch 171/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0173
# Epoch 172/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 279ms/step - accuracy: 0.9678 - loss: 0.0879 - val_accuracy: 1.0000 - val_loss: 0.0160
# Epoch 173/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.9723 - loss: 0.0636 - val_accuracy: 0.9500 - val_loss: 0.1080
# Epoch 174/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0365
# Epoch 175/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 285ms/step - accuracy: 0.9473 - loss: 0.1384 - val_accuracy: 0.9500 - val_loss: 0.3132
# Epoch 176/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.9254 - loss: 0.1448 - val_accuracy: 0.9750 - val_loss: 0.0372
# Epoch 177/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.0761
# Epoch 178/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - accuracy: 0.9404 - loss: 0.1850 - val_accuracy: 0.9750 - val_loss: 0.0492
# Epoch 179/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.9386 - loss: 0.1338 - val_accuracy: 0.9750 - val_loss: 0.0815
# Epoch 180/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0229
# Epoch 181/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.9633 - loss: 0.1285 - val_accuracy: 1.0000 - val_loss: 0.0642
# Epoch 182/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9659 - loss: 0.0921 - val_accuracy: 1.0000 - val_loss: 0.0206
# Epoch 183/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.0870
# Epoch 184/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 350ms/step - accuracy: 0.9349 - loss: 0.1480 - val_accuracy: 0.9750 - val_loss: 0.0609
# Epoch 185/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - accuracy: 0.8852 - loss: 0.2728 - val_accuracy: 1.0000 - val_loss: 0.0547
# Epoch 186/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.0641
# Epoch 187/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 278ms/step - accuracy: 0.9429 - loss: 0.1301 - val_accuracy: 0.9750 - val_loss: 0.0927
# Epoch 188/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9714 - loss: 0.0933 - val_accuracy: 0.9250 - val_loss: 0.2294
# Epoch 189/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1630
# Epoch 190/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - accuracy: 0.9635 - loss: 0.0969 - val_accuracy: 0.9250 - val_loss: 0.1275
# Epoch 191/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9169 - loss: 0.2368 - val_accuracy: 0.9500 - val_loss: 0.1041
# Epoch 192/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.9500 - val_loss: 0.1407
# Epoch 193/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 285ms/step - accuracy: 0.9403 - loss: 0.1137 - val_accuracy: 1.0000 - val_loss: 0.0441
# Epoch 194/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.9769 - loss: 0.0835 - val_accuracy: 1.0000 - val_loss: 0.0559

# %% [markdown]
# ## Plotting Accuracy and Loss Functions

# %%
import matplotlib.pyplot as plt

# Plot the accuracy and loss functions
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# ## Confusion Matrix

# %%
import seaborn
y_pred = model.predict(validation_generator, 20)
print('Confusion Matrix')
y_predicted_labels = y_pred > 0.5

size = np.size(y_predicted_labels)
y_predicted_labels = y_predicted_labels.reshape(size, )

for i in range (1, 5):
  total = i * size // 4
  mid = 49
  start = mid-((total+1)//2)+1
  end = mid+((total+1)//2)
  cm = tf.math.confusion_matrix(labels=validation_generator.labels[start:end],predictions=y_predicted_labels[start:end])

  # Calculate accuracy
  cm_np = cm.numpy()
  conf_acc = (cm_np[0, 0] + cm_np[1, 1])/ np.sum(cm_np) * 100
  print("Accuracy for", str(total), "Test Data = ", conf_acc)

  # Plot the confusion matrix
  plt.figure(figsize = (10,7))
  seaborn.heatmap(cm, annot=True, fmt='d')
  plt.title("Confusion Matrix for " + str(total) + " Test Data")
  plt.xlabel('Predicted')
  plt.ylabel('Expected')

# %% [markdown]
# ## Saving the model

# %%
# Save and convert the model (Used for deploying in web application)
model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape=(150, 150, 3)),  # Use input_shape instead of batch_shape
    # Add other layers...
])

model.save('model/image_model.h5')
print("Saved the model successfully")

# !apt-get -qq install virtualenv
# !virtualenv -p python3 venv
# !source venv/bin/activate
# !pip install -q tensorflowjs
# !tensorflowjs_converter --input_format=keras /content/model/image_model.h5 /content/image_model
print("Model converted to JSON successfully")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved the model successfully
# created virtual environment CPython3.10.12.final.0-64 in 194ms
#   creator CPython3Posix(dest=/content/venv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==22.0.2, setuptools==59.6.0, wheel==0.37.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
# /bin/bash: line 1: venv/bin/activate: No such file or directory
# 2024-09-06 07:38:34.454637: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-06 07:38:34.474441: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-06 07:38:34.480825: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-06 07:38:35.549885: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# failed to lookup keras version from the file,
#     this is likely a weight only file
# Model converted to JSON successfully

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.17.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, requests, setuptools, six, tensorboard, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by: dopamine_rl, tensorflow_decision_forests, tensorflowjs, tf_keras

# %% [markdown]
# ## Sample Example

# %%
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()
result = dict()

for fn in uploaded.keys():

  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(150, 150))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " - Sensitive")
    result[fn] = "Sensitive"
  else:
    print(fn + " - Non-sensitive")
    result[fn] = "Non-sensitive"

plt.figure(figsize=(20,20))

for i, fn in enumerate(uploaded.keys()):
  image = plt.imread(fn)
  plt.subplot(5, 5, i+1)
  plt.axis("off")
  plt.imshow(image)
  ans = fn + ": " + result[fn]
  plt.title(ans)
